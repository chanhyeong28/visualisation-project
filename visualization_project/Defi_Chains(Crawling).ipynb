# %%
import pandas as pd
import re
import json
import requests
import urllib.request as req

# %%
pc = pd.read_csv("chain-dataset-All2.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pc = pd.read_csv("data/chain-dataset-All2.csv")
#
# NameError: name 'pd' is not defined

# %%
pc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 pc
#
# NameError: name 'pc' is not defined

# %%
pc

# %%
pc.loc[pc["20/03/2023"].isnull()]
# Out:
#                Protocol  16/08/2018  17/08/2018  18/08/2018  19/08/2018  \
# 44              Bepswap         NaN         NaN         NaN         NaN
# 57              Dracula         NaN         NaN         NaN         NaN
# 68         Dev Protocol         NaN         NaN         NaN         NaN
# 70               SynLev         NaN         NaN         NaN         NaN
# 77         N3RD Finance         NaN         NaN         NaN         NaN
# ...                 ...         ...         ...         ...         ...
# 1902        Y2B Finance         NaN         NaN         NaN         NaN
# 1930      Doglands Swap         NaN         NaN         NaN         NaN
# 1959           Brewlabs         NaN         NaN         NaN         NaN
# 1970          Manifesto         NaN         NaN         NaN         NaN
# 2005  Mosquitos Finance         NaN         NaN         NaN         NaN
#
#       20/08/2018  21/08/2018  22/08/2018  23/08/2018  24/08/2018  ...  \
# 44           NaN         NaN         NaN         NaN         NaN  ...
# 57           NaN         NaN         NaN         NaN         NaN  ...
# 68           NaN         NaN         NaN         NaN         NaN  ...
# 70           NaN         NaN         NaN         NaN         NaN  ...
# 77           NaN         NaN         NaN         NaN         NaN  ...
# ...          ...         ...         ...         ...         ...  ...
# 1902         NaN         NaN         NaN         NaN         NaN  ...
# 1930         NaN         NaN         NaN         NaN         NaN  ...
# 1959         NaN         NaN         NaN         NaN         NaN  ...
# 1970         NaN         NaN         NaN         NaN         NaN  ...
# 2005         NaN         NaN         NaN         NaN         NaN  ...
#
#         11/03/2023    12/03/2023    13/03/2023    14/03/2023    15/03/2023  \
# 44             NaN           NaN           NaN           NaN           NaN
# 57             NaN           NaN           NaN           NaN           NaN
# 68             NaN           NaN           NaN           NaN           NaN
# 70             NaN           NaN           NaN           NaN           NaN
# 77             NaN           NaN           NaN           NaN           NaN
# ...            ...           ...           ...           ...           ...
# 1902           NaN           NaN           NaN           NaN           NaN
# 1930           NaN           NaN           NaN           NaN           NaN
# 1959  9.105811e+06  1.723179e+07  1.828299e+07  1.944196e+07  1.897084e+07
# 1970           NaN           NaN           NaN           NaN           NaN
# 2005           NaN           NaN           NaN           NaN           NaN
#
#         16/03/2023  17/03/2023  18/03/2023  19/03/2023  20/03/2023
# 44             NaN         NaN         NaN         NaN         NaN
# 57             NaN         NaN         NaN         NaN         NaN
# 68             NaN         NaN         NaN         NaN         NaN
# 70             NaN         NaN         NaN         NaN         NaN
# 77             NaN         NaN         NaN         NaN         NaN
# ...            ...         ...         ...         ...         ...
# 1902           NaN         NaN         NaN         NaN         NaN
# 1930           NaN         NaN         NaN         NaN         NaN
# 1959  1.896373e+07         NaN         NaN         NaN         NaN
# 1970           NaN         NaN         NaN         NaN         NaN
# 2005           NaN         NaN         NaN         NaN         NaN
#
# [109 rows x 1679 columns]

# %%
pc

# %%
pc_list = pc["Protocol"][2:]

# %%
pc_list = pc_list.tolist()

# %%
len(pc_list)
# Out:
# 2069

# %%
for i in range(len(pc_list)):
    pc_list[i] = pc_list[i].replace(" ","-")

# %%
add_list = []
for i in range(len(pc_list)):
    add_list.append("https://defillama.com/_next/data/FzgqchTXLOEvMRf0CUivw/protocol/"+str(pc_list[i])+".json?protocol="+str(pc_list[i]))

# %%
len(add_list)
# Out:
# 2069

# %%
add_list_ = add_list[0:]

# %%
for i in add_list_:
    r = requests.get(i)
    defi = r.json()
    defi_list_result.append(
        {
            'name' : defi['pageProps']['protocolData']['name'],
            'logo' :  defi['pageProps']['protocolData']['logo']
            'category' : defi['pageProps']['protocolData']['category'],
            'chain' : defi['pageProps']['protocolData']['chain'],
            'description' : defi['pageProps']['protocolData']['description'],
            'currentChainTvls': defi['pageProps']['protocolData']['currentChainTvls']
        }
    )
